# %% [markdown]
# # model ciconia ciconia

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import os
from pmdarima.arima import auto_arima
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df_ciconia_ciconia = pd.read_csv("df_Ciconia_ciconia")

# %%
df_ciconia_ciconia.head()
# Out:
#    Unnamed: 0            eventDate  year  month  day continent   Country  \
# 0           0  2015-07-15T06:00:00  2015      7   15    EUROPE  Slovenia
# 1           1  2015-07-15T06:00:00  2015      7   15    EUROPE  Slovenia
# 2           2  2015-07-15T09:00:00  2015      7   15    EUROPE  Slovenia
# 3           3  2015-07-15T09:00:00  2015      7   15    EUROPE  Slovenia
# 4           4  2015-07-15T12:00:00  2015      7   15    EUROPE  Slovenia
#
#                 City           Specie
# 0  Osrednjeslovenska  Ciconia ciconia
# 1  Osrednjeslovenska  Ciconia ciconia
# 2  Osrednjeslovenska  Ciconia ciconia
# 3  Osrednjeslovenska  Ciconia ciconia
# 4  Osrednjeslovenska  Ciconia ciconia

# %%
df_ciconia_ciconia["eventDate"] = pd.to_datetime(df_ciconia_ciconia["eventDate"])

df_ciconia_ciconia["eventDate"]= df_ciconia_ciconia["eventDate"].dt.strftime('%d/%m/%Y')

# %%
df_ciconia_ciconia.drop("Unnamed: 0", axis =1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df_ciconia_ciconia.drop("Unnamed: 0", axis =1, inplace = True)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
# ...

# %%
df_ciconia_ciconia.set_index(df_ciconia_ciconia["eventDate"], inplace=True)

# %%
# df_ciconia_ciconia.drop(["eventDate"], axis= 1, inplace = True)

# %%
df_ciconia_ciconia
# Out:
#              eventDate  year  month  day continent   Country  \
# eventDate
# 15/07/2015  15/07/2015  2015      7   15    EUROPE  Slovenia
# 15/07/2015  15/07/2015  2015      7   15    EUROPE  Slovenia
# 15/07/2015  15/07/2015  2015      7   15    EUROPE  Slovenia
# 15/07/2015  15/07/2015  2015      7   15    EUROPE  Slovenia
# 15/07/2015  15/07/2015  2015      7   15    EUROPE  Slovenia
# ...                ...   ...    ...  ...       ...       ...
# 29/11/2016  29/11/2016  2016     11   29    AFRICA     Kenya
# 29/11/2016  29/11/2016  2016     11   29    AFRICA     Kenya
# 29/11/2016  29/11/2016  2016     11   29    AFRICA     Kenya
# 30/11/2016  30/11/2016  2016     11   30    AFRICA     Kenya
# 30/11/2016  30/11/2016  2016     11   30    AFRICA     Kenya
#
#                          City           Specie
# eventDate
# 15/07/2015  Osrednjeslovenska  Ciconia ciconia
# 15/07/2015  Osrednjeslovenska  Ciconia ciconia
# 15/07/2015  Osrednjeslovenska  Ciconia ciconia
# ...

# %%
plt.figure(figsize=(10,6))
plt.xlabel("Event Date")
plt.ylabel("continent")
plt.scatter(df_ciconia_ciconia["eventDate"],y=df[""])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 4
#       2 plt.xlabel("Event Date")
#       3 plt.ylabel("continent")
# ----> 4 df_ciconia_ciconia["continent"].plot( kind= "kde")
#
# File ~/.local/lib/python3.10/site-packages/pandas/plotting/_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...
